# %%
import sys
sys.path.append('../')
#sys.path.append('../../kilca_interface/')
from pyABC import *
from GPEC_interface import *
import os
#from InpOut import InpOut

cur_path = os.getcwd()

fluxpath = os.path.join(cur_path, './fluxdata/')
#gfilepath = '/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance/python/pyABC/testing/g33353.2700_EQH'
cfilepath = '/proj/plasma/DATA/BALANCE/COIL/33353/33353.2900_coil.dat'
gfilepath = '/proj/plasma/DATA/BALANCE/EQUI/33353/g33353.2900_MICDU_EQB_ed1'
path_da = '/temp/markl_m/DA/ASTRA/'
profpath = os.path.join(cur_path, 'run/profiles')

abc = pyABC(33353, 2900, './run/', 'name')

m = np.array([5,6,7])
n = np.array([2,2,2])

abc.set_modes(m,n)
abc.set_profiles(profpath)
abc.set_coil(cfilepath)
abc.set_equi(gfilepath, fluxpath)

#abc.run_TMHD_code('./gpec/')

# %%
abc.set_Da_estimation(path_da)
# Out:
# /afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance/python/pyABC/testing/./run/profiles
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-6e76024726fd> in <module>
# ----> 1 abc.set_Da_estimation(path_da)
#
# ~/Dokumente/plasma/code/balance/python/pyABC/pyABC.py in set_Da_estimation(self, path_da)
#     220         flag_combined = True
#     221
# --> 222         self.da_est = da_estimator(self.path_profiles, self.flux_data_path)
#     223         self.da_est.load_estimation(self.shot, self.time_slice, path_da, flag_combined)
#     224
#
# ~/Dokumente/plasma/code/balance/python/pyABC/da_estimator.py in __init__(self, profpath, fluxdatapath)
#      68         # load raw profiles
#      69         print(profpath)
# ---> 70         ne_raw = np.loadtxt(profpath + 'n.dat')
#      71         Te_raw = np.loadtxt(profpath + 'Te.dat')
#      72
#
# /usr/lib/python3/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# /usr/lib/python3/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# /usr/lib/python3/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: /afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance/python/pyABC/testing/./run/profilesn.dat not found.

# %%
abc.da_est.V
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c5344df67ad0> in <module>
# ----> 1 abc.da_est.V
#
# AttributeError: 'pyABC' object has no attribute 'da_est'

# %%
gp = GPEC_interface('./gpec/', 33353, 3200, 'name')
gp.setEqui(gfilepath)
gp.setCoil(cfilepath)
gp.write()
# Out:
# 16

# %%
curr_path = os.getcwd()
os.chdir(abc.fourier_path)
res = subprocess.Popen('./fouriermodes.x', shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, executable='/bin/bash')
print(res)
os.chdir(curr_path)
# Out:
# <Popen: returncode: None args: ['.', '/', 'f', 'o', 'u', 'r', 'i', 'e', 'r',...>

# %%
print(res.stderr.read().decode('UTF-8'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-24f72a7267a9> in <module>
# ----> 1 print(res.stderr.read().decode('UTF-8'))
#
# KeyboardInterrupt:

# %%
m = np.array([5,6,7])

# %%
isinstance(m, np.ndarray)
# Out:
# True

# %%
abc.fourier_path + 'fouriermodes.x'
# Out:
# '/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance/matlab/fourier/fouriermodes.x'

# %%
gp.run_code('dcon')
# Out:
# /proj/plasma/CODE/GPEC/dcon/dcon
# Start of dcon at 2023-03-01 13:54:56.658076
# Shot: 33353, Time: 3200ms, Name: name
# Finished dcon at 2023-03-01 13:55:27.951849
# Total runtime was 0:00:31.293887

# %%
conflist = "".join(gp.getConf()).split()
print(conflist)
# Out:
# ['source', '/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh', 'intel64', ';', 'export', 'FC=ifort', ';', 'export', 'F77=ifort', ';', 'export', 'F90=ifort', ';', 'export', 'CC=icc', ';', 'export', 'CXX=icc', ';', 'export', 'PROJLIBS=/proj/plasma/Libs/intel', ';', 'export', 'NETCDFHOME=$PROJLIBS/NetCDF', ';', 'export', 'CFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'FFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'CXXFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'LDFLAGS=-L$NETCDFHOME/lib/', ';', 'export', 'LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH', ';', 'export', 'F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1', ';', 'export', 'GPECHOME=/proj/plasma/CODE/GPEC/', ';', 'ulimit', '-s', 'unlimited']

# %%
t = conflist
print(conflist.insert(len(conflist), 'test'))
# Out:
# None

# %%
print(conflist)
# Out:
# ['source', '/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh', 'intel64', ';', 'export', 'FC=ifort', ';', 'export', 'F77=ifort', ';', 'export', 'F90=ifort', ';', 'export', 'CC=icc', ';', 'export', 'CXX=icc', ';', 'export', 'PROJLIBS=/proj/plasma/Libs/intel', ';', 'export', 'NETCDFHOME=$PROJLIBS/NetCDF', ';', 'export', 'CFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'FFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'CXXFLAGS=-I$NETCDFHOME/include/', ';', 'export', 'LDFLAGS=-L$NETCDFHOME/lib/', ';', 'export', 'LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH', ';', 'export', 'F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1', ';', 'export', 'GPECHOME=/proj/plasma/CODE/GPEC/', ';', 'ulimit', '-s', 'test', 'unlimited', 'test']

# %%
t
# Out:
# ['source',
#  '/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh',
#  'intel64',
#  ';',
#  'export',
#  'FC=ifort',
#  ';',
#  'export',
#  'F77=ifort',
#  ';',
#  'export',
#  'F90=ifort',
#  ';',
#  'export',
#  'CC=icc',
#  ';',
#  'export',
#  'CXX=icc',
#  ';',
#  'export',
#  'PROJLIBS=/proj/plasma/Libs/intel',
#  ';',
#  'export',
#  'NETCDFHOME=$PROJLIBS/NetCDF',
#  ';',
#  'export',
#  'CFLAGS=-I$NETCDFHOME/include/',
#  ';',
#  'export',
#  'FFLAGS=-I$NETCDFHOME/include/',
#  ';',
#  'export',
#  'CXXFLAGS=-I$NETCDFHOME/include/',
#  ';',
#  'export',
#  'LDFLAGS=-L$NETCDFHOME/lib/',
#  ';',
#  'export',
#  'LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH',
#  ';',
#  'export',
#  'F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1',
#  ';',
#  'export',
#  'GPECHOME=/proj/plasma/CODE/GPEC/',
#  ';',
#  'ulimit',
#  '-s',
#  'unlimited',
#  ['test'],
#  'test',
#  'test',
#  'test',
#  'test',
#  ['test']]

# %%
print(conflist.append(['test']))
# Out:
# None

# %%
import os
os.system('ln -sfT ' + gp.gpec_home + 'dcon' + '/' + 'dcon' + ' ./' + 'dcon')
# Out:
# 0

# %%
pypath = os.getcwd()
os.chdir('gpec/')
print(os.getcwd())
out = subprocess.Popen(["".join(gp.getConf()) + ' ; ./dcon')
#ret = os.popen('./dcon').read()
os.chdir(pypath)
# Out:
# /afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance/python/pyABC/testing/gpec

# %%
out = os.system("/bin/bash -c source /afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh intel64")

# %%
import subprocess

out = subprocess.Popen(["source", "/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh", "intel64"], executable='/bin/bash', stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(out.communicate())
# Out:
# (b'', b'')

# %%
for el in "".join(gp.getConf()).split(';'):
    print(el.split())
# Out:
# ['source', '/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh', 'intel64']
# ['export', 'FC=ifort']
# ['export', 'F77=ifort']
# ['export', 'F90=ifort']
# ['export', 'CC=icc']
# ['export', 'CXX=icc']
# ['export', 'PROJLIBS=/proj/plasma/Libs/intel']
# ['export', 'NETCDFHOME=$PROJLIBS/NetCDF']
# ['export', 'CFLAGS=-I$NETCDFHOME/include/']
# ['export', 'FFLAGS=-I$NETCDFHOME/include/']
# ['export', 'CXXFLAGS=-I$NETCDFHOME/include/']
# ['export', 'LDFLAGS=-L$NETCDFHOME/lib/']
# ['export', 'LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH']
# ['export', 'F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1']
# ['export', 'GPECHOME=/proj/plasma/CODE/GPEC/']
# ['ulimit', '-s', 'unlimited']

# %%
import subprocess
subprocess.Popen(''.join(gp.getConf()) + ' ; :/' +'dcon', shell=True)
# Out:
# <Popen: returncode: None args: ['/', 'b', 'i', 'n', '/', 'b', 'a', 's', 'h',...>

# %%
subprocess.Popen('source')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-2266d15ebe0d> in <module>
# ----> 1 subprocess.Popen('source')
#
# /usr/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     949                             encoding=encoding, errors=errors)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#     953                                 startupinfo, creationflags, shell,
#
# /usr/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1821                     if errno_num != 0:
#    1822                         err_msg = os.strerror(errno_num)
# -> 1823                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1824                 raise child_exception_type(err_msg)
#    1825
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source'

# %%
for el in gp.getConf():
    print(el.split())
# Out:
# ['source', '/afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh', 'intel64', ';']
# ['export', 'FC=ifort', ';']
# ['export', 'F77=ifort', ';']
# ['export', 'F90=ifort', ';']
# ['export', 'CC=icc', ';']
# ['export', 'CXX=icc', ';']
# ['export', 'PROJLIBS=/proj/plasma/Libs/intel', ';']
# ['export', 'NETCDFHOME=$PROJLIBS/NetCDF', ';']
# ['export', 'CFLAGS=-I$NETCDFHOME/include/', ';']
# ['export', 'FFLAGS=-I$NETCDFHOME/include/', ';']
# ['export', 'CXXFLAGS=-I$NETCDFHOME/include/', ';']
# ['export', 'LDFLAGS=-L$NETCDFHOME/lib/', ';']
# ['export', 'LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH', ';']
# ['export', 'F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1', ';']
# ['export', 'GPECHOME=']
# ['/proj/plasma/CODE/GPEC/']
# [';']
# ['ulimit', '-s', 'unlimited']

# %%
np.reshape(gp.current,(7,2)).tolist()
# Out:
# [[1265.1824951171875, 1247.406005859375],
#  [-1252.899169921875, -1265.6402587890625],
#  [1266.7083740234375, 1249.237060546875],
#  [-1255.340576171875, 1271.4385986328125],
#  [-1272.430419921875, -1245.9564208984375],
#  [1245.1934814453125, 1270.599365234375],
#  [-1273.651123046875, -1249.0081787109375]]

# %%
''.join(gp.getConf()) + ' ; ./' + 'dcon'
# Out:
# 'source /afs/itp.tugraz.at/opt/intel/2018.1/bin/compilervars.sh intel64 ; export FC=ifort ; export F77=ifort ; export F90=ifort ; export CC=icc ; export CXX=icc ; export PROJLIBS=/proj/plasma/Libs/intel ; export NETCDFHOME=$PROJLIBS/NetCDF ; export CFLAGS=-I$NETCDFHOME/include/ ; export FFLAGS=-I$NETCDFHOME/include/ ; export CXXFLAGS=-I$NETCDFHOME/include/ ; export LDFLAGS=-L$NETCDFHOME/lib/ ; export LD_LIBRARY_PATH=$NETCDFHOME/lib/:$LD_LIBRARY_PATH ; export F90HOME=/afs/itp.tugraz.at/opt/intel/2018.1 ; export GPECHOME=/proj/plasma/CODE/GPEC/ ; ulimit -s unlimited ; ./dcon'

# %%
import numpy as np
5 + 5 * np.ceil(nwEQD/5) + np.ceil(nwEQD * nhEQD / 5)
# Out:
# 26634.0

# %%
5 +4 * np.ceil(nwEQD/5) + np.ceil(nwEQD * nhEQD / 5)
# Out:
# 26582.0
