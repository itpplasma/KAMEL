# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

profpath = '/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/dat/'

Er = np.loadtxt(profpath + 'Er.dat')
n = np.loadtxt(profpath + 'n.dat')
Te = np.loadtxt(profpath + 'Te.dat')
Ti = np.loadtxt(profpath + 'Ti.dat')
Vz = np.loadtxt(profpath + 'Vz.dat')
q = np.loadtxt(profpath + 'q.dat')
Vth = np.loadtxt(profpath + 'Vth.dat')

r = n[:,0]
Da = np.ones_like(r) * 1e4

rbig = 170.05
b_tor = -17563

h5file.close()
h5file = h5py.File('/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/hdf5/parabolic_profiles.hdf5', 'w')
dset = h5file.create_dataset('/preprocprof/r_out', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/preprocprof/n', np.shape(r))
dset[:] = n[:,1]
dset = h5file.create_dataset('/preprocprof/Te', np.shape(r))
dset[:] = Te[:,1]
dset = h5file.create_dataset('/preprocprof/Ti', np.shape(r))
dset[:] = Ti[:,1]
dset = h5file.create_dataset('/preprocprof/Vz', np.shape(r))
dset[:] = Vz[:,1]
dset = h5file.create_dataset('/preprocprof/Vth', np.shape(r))
dset[:] = Vth[:,1]
dset = h5file.create_dataset('/preprocprof/Er', np.shape(r))
dset[:] = Er[:,1]
dset = h5file.create_dataset('/preprocprof/q', np.shape(r))
dset[:] = q[:,1]

dset = h5file.create_dataset('/da_estimation/r', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/da_estimation/Da', np.shape(r))
dset[:] = Da

dset = h5file.create_dataset('/output/scalefactors_sq', (3,))
dset[:] = np.ones(3)

dset = h5file.create_dataset('/input/r_big', (1,))
dset[:] = rbig

dset = h5file.create_dataset('/input/b_tor', (1,))
dset[:] = b_tor


h5file.close()

# %%
profpath = '/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/dat/const_ne/'

Er = np.loadtxt(profpath + 'Er.dat')
n = np.loadtxt(profpath + 'n.dat')
Te = np.loadtxt(profpath + 'Te.dat')
Ti = np.loadtxt(profpath + 'Ti.dat')
Vz = np.loadtxt(profpath + 'Vz.dat')
q = np.loadtxt(profpath + 'q.dat')
Vth = np.loadtxt(profpath + 'Vth.dat')

r = n[:,0]
Da = np.ones_like(r) * 1e4

h5file.close()
h5file = h5py.File('/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/hdf5/parabolic_profiles_const_n.hdf5', 'w')
dset = h5file.create_dataset('/preprocprof/r_out', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/preprocprof/n', np.shape(r))
dset[:] = n[:,1]
dset = h5file.create_dataset('/preprocprof/Te', np.shape(r))
dset[:] = Te[:,1]
dset = h5file.create_dataset('/preprocprof/Ti', np.shape(r))
dset[:] = Ti[:,1]
dset = h5file.create_dataset('/preprocprof/Vz', np.shape(r))
dset[:] = Vz[:,1]
dset = h5file.create_dataset('/preprocprof/Vth', np.shape(r))
dset[:] = Vth[:,1]
dset = h5file.create_dataset('/preprocprof/Er', np.shape(r))
dset[:] = Er[:,1]
dset = h5file.create_dataset('/preprocprof/q', np.shape(r))
dset[:] = q[:,1]

dset = h5file.create_dataset('/da_estimation/r', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/da_estimation/Da', np.shape(r))
dset[:] = Da

dset = h5file.create_dataset('/output/scalefactors_sq', (3,))
dset[:] = np.ones(3)

h5file.close()

# %%
profpath = '/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/dat/const_Te/'

Er = np.loadtxt(profpath + 'Er.dat')
n = np.loadtxt(profpath + 'n.dat')
Te = np.loadtxt(profpath + 'Te.dat')
Ti = np.loadtxt(profpath + 'Ti.dat')
Vz = np.loadtxt(profpath + 'Vz.dat')
q = np.loadtxt(profpath + 'q.dat')
Vth = np.loadtxt(profpath + 'Vth.dat')

r = n[:,0]
Da = np.ones_like(r) * 1e4

h5file.close()
h5file = h5py.File('/afs/itp.tugraz.at/user/markl_m/Dokumente/plasma/code/balance_studies/data/parabolic_profiles/hdf5/parabolic_profiles_const_Te.hdf5', 'w')
dset = h5file.create_dataset('/preprocprof/r_out', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/preprocprof/n', np.shape(r))
dset[:] = n[:,1]
dset = h5file.create_dataset('/preprocprof/Te', np.shape(r))
dset[:] = Te[:,1]
dset = h5file.create_dataset('/preprocprof/Ti', np.shape(r))
dset[:] = Ti[:,1]
dset = h5file.create_dataset('/preprocprof/Vz', np.shape(r))
dset[:] = Vz[:,1]
dset = h5file.create_dataset('/preprocprof/Vth', np.shape(r))
dset[:] = Vth[:,1]
dset = h5file.create_dataset('/preprocprof/Er', np.shape(r))
dset[:] = Er[:,1]
dset = h5file.create_dataset('/preprocprof/q', np.shape(r))
dset[:] = q[:,1]

dset = h5file.create_dataset('/da_estimation/r', np.shape(r))
dset[:] = r
dset = h5file.create_dataset('/da_estimation/Da', np.shape(r))
dset[:] = Da

dset = h5file.create_dataset('/output/scalefactors_sq', (3,))
dset[:] = np.ones(3)

h5file.close()

# %%
np.shape(r)
# Out:
# (100,)

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])
